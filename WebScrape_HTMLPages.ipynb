# %% [markdown]
# <a href="https://colab.research.google.com/github/imshubhadeep/Web-Scraping/blob/main/WebScrape_HTMLPages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Simple Web Scraping on HTML page using pandas**

# %%
import pandas as pd

scrape = pd.read_html("https://en.wikipedia.org/wiki/Union_Government_ministries_of_India")

for idx, table in enumerate(scrape):
  print("*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*")
  print(idx)
  print(table)
# Out:
# *+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*+*
# 0
#                                           Minister  ...                                  Minister of State
# 0                    Agriculture & Farmers Welfare  ...              Shobha Karandlaje / Kailash Choudhary
# 1         Animal Husbandry, Dairying And Fisheries  ...              Sanjeev Kumar Balyan / Dr. L. Murugan
# 2                                            AYUSH  ...                         Dr. Munjapara Mahendrabhai
# 3                        Chemicals and Fertilizers  ...                                    Bhagwanth Khuba
# 4                                   Civil Aviation  ...                        General (Retd.) V. K. Singh
# 5                                             Coal  ...                             Danve Raosaheb Dadarao
# 6                            Commerce and Industry  ...                 Anupriya Singh Patel / Som Parkash
# ...

# %%
scrape[0]
# Out:
#                                           Minister  ...                                  Minister of State
# 0                    Agriculture & Farmers Welfare  ...              Shobha Karandlaje / Kailash Choudhary
# 1         Animal Husbandry, Dairying And Fisheries  ...              Sanjeev Kumar Balyan / Dr. L. Murugan
# 2                                            AYUSH  ...                         Dr. Munjapara Mahendrabhai
# 3                        Chemicals and Fertilizers  ...                                    Bhagwanth Khuba
# 4                                   Civil Aviation  ...                        General (Retd.) V. K. Singh
# 5                                             Coal  ...                             Danve Raosaheb Dadarao
# 6                            Commerce and Industry  ...                 Anupriya Singh Patel / Som Parkash
# 7                                   Communications  ...                                   Devusinh Chauhan
# ...

# %%
# To save this file in CSV_Format
df = pd.DataFrame(scrape[0])
new_df = df.fillna("NaN")
new_df.to_csv("/content/drive/MyDrive/123/DataSet.csv", index=True)
